# %%
#載入套件
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import RMSprop
from keras.utils import np_utils
from keras.callbacks import Callback,EarlyStopping
import numpy

# binary encode numbers
num_digits = 10 
# 四種類型：number/fizz/buzz/fizzbuzz
nb_classes = 4 
# batch_size 每一批次訓練筆數
batch_size = 128

# 設定題目規則
# 將每個十進位數轉換成二制進數組，比如 100 => [ 0,0,0,1,1,0,0,1,0,0] ,共10維。
# 其對應的標籤為：
# [0,0,0,1] => 'Fizz'
# [0,0,1,0] =>'Buzz'
# [0,1,0,0] =>'FizzBuzz'
# [1,0,0,0] =>'其它'共4維


def fb_encode(i):
    if   i % 15 == 0: return [3]
    elif i % 5  == 0: return [2]
    elif i % 3  == 0: return [1]
    else:             return [0]

def bin_encode(i):
    return [i >> d & 1 for d in range(num_digits)]

def fizz_buzz_pred(i, pred):
    return [str(i), "fizz", "buzz", "fizzbuzz"][pred.argmax()]


def fizz_buzz(i):
    if   i % 15 == 0: return "fizzbuzz"
    elif i % 5  == 0: return "buzz"
    elif i % 3  == 0: return "fizz"
    else:             return str(i)

# 劃分訓練集跟測試集
def create_dataset(start, end):
    dataX,dataY = [],[]
    for i in range(start,end):
        dataX.append(bin_encode(i))
        dataY.append(fb_encode(i))
    return numpy.array(dataX),np_utils.to_categorical(numpy.array(dataY), nb_classes)


x_train,y_train = create_dataset(101,1001)
x_test,y_test = create_dataset(1,101)

# %%
#訓練集
x_train.shape
x_train[0]
# Out:
# array([1, 0, 1, 0, 0, 1, 1, 0, 0, 0])

# %%
#測試集
y_train.shape
y_train[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %%
#建立 keras的Sequential model
model = Sequential()

# 建立dense層，輸入為10個神經元，輸出為1000個神經元
# Activation Function為  relu
model.add(Dense(input_dim=10, units=1000))
model.add(Activation('relu'))

# 建立dense層，輸入為上層的輸出，輸出為4個神經元
# Activation Function為 softmax
model.add(Dense(units=4))
model.add(Activation('softmax'))

#定義模型訓練方式：
#設定loss function
#optimizer 設定優化器
#設定評估模型的方式為 accuracy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#設定訓練資料參數
#設定訓言資料與驗證資料比例
#設定epoch訓練週期
model.fit(x_train,y_train,batch_size=20, epochs=100)

#預測準確率
result = model.evaluate(x_test,y_test)
score = model.evaluate(x_train,y_train)
print('\nTrain Acc:', score[1])
result = model.evaluate(x_test,y_test)
print('\nTest Acc:', result[1])
# Out:
# Epoch 1/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.1910 - accuracy: 0.5167
# Epoch 2/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1567 - accuracy: 0.5333
# Epoch 3/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1450 - accuracy: 0.5333
# Epoch 4/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.1412 - accuracy: 0.5333
# Epoch 5/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1391 - accuracy: 0.5333
# Epoch 6/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1346 - accuracy: 0.5333
# Epoch 7/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1144 - accuracy: 0.5333
# Epoch 8/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0999 - accuracy: 0.5333
# Epoch 9/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0832 - accuracy: 0.5333
# Epoch 10/100
# 45/45 [==============================] - 0s 5ms/step - loss: 1.0722 - accuracy: 0.5344
# Epoch 11/100
# 45/45 [==============================] - 0s 5ms/step - loss: 1.0452 - accuracy: 0.5333
# Epoch 12/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0293 - accuracy: 0.5378
# Epoch 13/100
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0024 - accuracy: 0.5378
# Epoch 14/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.9792 - accuracy: 0.5589
# Epoch 15/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.9487 - accuracy: 0.5600
# Epoch 16/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.9247 - accuracy: 0.5600
# Epoch 17/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.8952 - accuracy: 0.5811
# Epoch 18/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.8719 - accuracy: 0.5889
# Epoch 19/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.8465 - accuracy: 0.5911
# Epoch 20/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.8122 - accuracy: 0.6278
# Epoch 21/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7869 - accuracy: 0.6522
# Epoch 22/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7556 - accuracy: 0.6789
# Epoch 23/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7422 - accuracy: 0.6889
# Epoch 24/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7081 - accuracy: 0.7256
# Epoch 25/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6787 - accuracy: 0.7500
# Epoch 26/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6523 - accuracy: 0.7600
# Epoch 27/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6257 - accuracy: 0.7933
# Epoch 28/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.8300
# Epoch 29/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.8533
# Epoch 30/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.5553 - accuracy: 0.8500
# Epoch 31/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.5226 - accuracy: 0.8833
# Epoch 32/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.8967
# Epoch 33/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4834 - accuracy: 0.9111
# Epoch 34/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4575 - accuracy: 0.9256
# Epoch 35/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4366 - accuracy: 0.9289
# Epoch 36/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4166 - accuracy: 0.9422
# Epoch 37/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4023 - accuracy: 0.9433
# Epoch 38/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3846 - accuracy: 0.9533
# Epoch 39/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3659 - accuracy: 0.9600
# Epoch 40/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3456 - accuracy: 0.9667
# Epoch 41/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3289 - accuracy: 0.9722
# Epoch 42/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3120 - accuracy: 0.9789
# Epoch 43/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2975 - accuracy: 0.9800
# Epoch 44/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.9844
# Epoch 45/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2774 - accuracy: 0.9833
# Epoch 46/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2598 - accuracy: 0.9900
# Epoch 47/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2467 - accuracy: 0.9878
# Epoch 48/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2369 - accuracy: 0.9922
# Epoch 49/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2257 - accuracy: 0.9956
# Epoch 50/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2142 - accuracy: 0.9933
# Epoch 51/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2024 - accuracy: 0.9956
# Epoch 52/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1937 - accuracy: 0.9978
# Epoch 53/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1867 - accuracy: 0.9978
# Epoch 54/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1766 - accuracy: 0.9989
# Epoch 55/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1672 - accuracy: 0.9989
# Epoch 56/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9967
# Epoch 57/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9989
# Epoch 58/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1475 - accuracy: 0.9989
# Epoch 59/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1402 - accuracy: 0.9989
# Epoch 60/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9989
# Epoch 61/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.9989
# Epoch 62/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.9989
# Epoch 63/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.9989
# Epoch 64/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1136 - accuracy: 0.9989
# Epoch 65/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9989
# Epoch 66/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9989
# Epoch 67/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0979 - accuracy: 0.9989
# Epoch 68/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9989
# Epoch 69/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9989
# Epoch 70/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9989
# Epoch 71/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 72/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9989
# Epoch 73/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 74/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9989
# Epoch 75/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0727 - accuracy: 0.9989
# Epoch 76/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9989
# Epoch 77/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9989
# Epoch 78/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 79/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 1.0000
# Epoch 80/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 81/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 82/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 83/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 84/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 85/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 86/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9989
# Epoch 87/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 88/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 89/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 90/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 91/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 92/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 93/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 94/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 95/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 96/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 97/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 98/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 99/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 100/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 1.0000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
#
# Train Acc: 1.0
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 1.0000
#
# Test Acc: 1.0

# %%
def fizz_buzz(n): 
    for i in range(1, n+1):
        result = ''
        if i%3 == 0:
            result += 'Fizz'
        if i%5 == 0:
            result += 'Buzz'
        if len(result)>0:
            print(result)
        else:
            print(i)

# %%
fizz_buzz(100)
