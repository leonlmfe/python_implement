# %%
import numpy as np
import matplotlib.pyplot as plt
x= [10,20,16,23,15,11,16,17,13,16,33,21,18,23,13,20,16,11,25,27]
plt.plot(x, label='bfs')
plt.xlabel('number of times')
plt.ylabel('length')
plt.title("snake game")
plt.legend()
plt.show()
